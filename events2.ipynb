# %% [markdown]
# # Events
#
# Les Catherines perform in venues across Boulder County and the Denver area, bringing acoustic music to both intimate spaces and larger public settings.

# %% [markdown]
# ## Upcoming Events
#
# ### CBArt Studios Open Mic
# **Friday, June 5, 2026**
# **6:00–8:00 PM**
# Superior, Colorado
#
# An evening of live music in a warm and welcoming community setting.
#
# ---
#
# ### More dates coming soon
# Please check back for future performances.

# %% [markdown]
# ## Featured Venues
#
# We regularly perform in welcoming local venues, including:
#
# - **CBArt Studios** — Superior
# - **Tandoori Grill** — Louisville
#
# We have also been invited to perform at:
#
# - **Alliance Française de Denver**
# - **Cherry Creek Shopping Center**

# %% [markdown]
# ## Recent Performances
#
# ### CBArt Studios
# Superior, Colorado
#
# ### Tandoori Grill
# Louisville, Colorado
#
# ### Alliance Française de Denver
# Denver, Colorado
#
# ### Cherry Creek Shopping Center
# Denver, Colorado

# %% [markdown]
# ## Booking & Inquiries
#
# For performance inquiries, please visit our [Contact](contact) page.
