# %% [markdown]
# # LIVE PERFORMANCES
#
# ---
#
# ![Les Catherines live](images/frenchfest2026.png)

# %% [markdown]
# Les Catherines performs at intimate venues, restaurants, festivals, private gatherings, and community events across Boulder County and the Denver area.
#
# Our repertoire moves across languages, cultures, and musical styles, taking the audience on an acoustic voyage around the world.
#
#
# ::: {.card}
# ### Upcoming shows
#
# - **September 11, 2026** · CBArt Studios, Superior
# **(More info coming soon)**
#
# - **October 10, 2026** · Tandoori Grill, Boulder
# **(More info coming soon)**
#
# - **November 14, 2026** · Duets, Longmont
# **(More info coming soon)**
#
# For the latest event details and announcements, visit our [Stay Connected →](contact) page.
#
# ### Recent past shows
#
# - **August 22, 2026** · Duets, Longmont
# **([View flyer](images/2026-08-22-Duets.jpg))**
#
# - **July 12, 2026** · French Fest, Cherry Creek
# **([Event details](https://denverfrenchfest.com/))**
#
# - **July 11, 2026** · The Muse, Lafayette
# **([Event details](https://www.giftedherd.org/po-benefit-concert))**
#
# - **June 27, 2026** · Tandoori Grill, Boulder
# **([View flyer](images/Tandoori2026-06-27.jpg))**
#
# - **June 20, 2026** · Littleton Brewery, Denver
# **([Event details](https://www.afdenver.org/event-rsvp/la-fete-de-la-musique-2026/))**
#
# :::
#
#
# ## From a live performance
#
# Our live performances is really about the experience and the connection we create with the audience. Here is a glimpse of one of our live performances:
#
# :::{iframe} https://www.youtube.com/embed/AZPmAJtijfY
# :width: 100%
# :title: Les Catherines live performance
# :::
#
# For more videos, visit our [YouTube channel](https://www.youtube.com/@LesCatherines).
