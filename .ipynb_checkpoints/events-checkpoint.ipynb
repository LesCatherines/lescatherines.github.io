# %% [markdown]
# # EVENTS
#
# Les Catherines regularly perform as a trio in intimate venues, restaurants and outdoor spaces, across Boulder County and the Denver area. Alongside these performances, we also foster a local music community through the CBArt Studios Open Mic in Superior.
#
# Upcoming events and updates are regularly announced on our [social media →](contact)
#
# ----
#
# ## Les Catherines Performances
#
# ::::{grid} 2
# :gap: 2
# :class: responsive-grid
# :::{grid-item}
# Our trio performances feature a multilingual repertoire, blending styles, and interpretations into a warm and engaging musical experience. Previous venues include: CBArt Studios in Superior, Tandoori Grill in Boulder, the Alliance Française in Denver, Flagstaff Auditorium and the Cherry Creek Shopping Center.
#
# :::
#
# :::{grid-item}
#
# ```{image} images/catherines-flagstaff.jpg
# :alt: Les Catherines
# :width: 220px
# :class: about-photo
# ```
# :::
# ::::
#
# ### Upcoming performances
# - **April 25, 2026: Alliance Française de Denver**, Denver, Colorado   </n></n>
#
# - **June 20, 2026: World Music Day**. Denver, Colorado </n></n>
#
# [→ More info about upcoming performances on Facebook/Instagram ](contact)
#
# ---
#
# ## Music Community — CBArt Studios Open Mic
#
# ::::{grid} 2
# :gap: 2
# :class: responsive-grid
# :::{grid-item}
# In addition to performing, we organize and run the CBArt Studios Open Mic in Superior, a recurring gathering where musicians and listeners come together in a relaxed and supportive setting.
#
# Thanks to the generosity of CBArt Studios, which provides their beautiful space for live music, the open mic takes place on the first Friday of every other month. It is an evening dedicated to sharing music, discovering new voices, and creating connections within the local community.
#
# :::
#
#
# :::{grid-item}
# <video class="about-photo" width="220" controls>
#   <source src="{static}/images/openmic.mp4" type="video/mp4">
#   Your browser does not support the video tag.
# </video>
# :::
# ::::
#
#
# ### Next Open Mic
# June 5, 2026 · 6:00–8:00 PM · Superior, Colorado
#
# [→ More information about our open mic on Facebook/Instagram →](contact)
#
#
# <video width="320" controls>
#   <source src="./images/openmic.mp4" type="video/mp4">
# </video>
