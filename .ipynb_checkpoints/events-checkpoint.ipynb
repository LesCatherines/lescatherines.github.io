# %% [markdown]
# # EVENTS
#
# Les Catherines regularly perform as a trio in intimate venues, restaurants and outdoor spaces, across Boulder County and the Denver area.
#
# We also host the CBArt Studios Open Mic in Superior, a relaxed gathering for musicians and listeners.
#
# Upcoming events and updates are regularly announced on our [social media →](contact)
#
# ----
#
# (performances)=
# ## Les Catherines Performances
#
# ::::{grid} 2
# :gap: 2
# :class: responsive-grid
# :::{grid-item}
#
# Our trio performances feature a multilingual repertoire, blending styles and interpretations into a warm and engaging musical experience.
#
# We have performed at venues including CBArt Studios in Superior, Tandoori Grill in Boulder, the Alliance Française in Denver, Flagstaff Auditorium, and Cherry Creek Shopping Center.
#
# :::
#
# :::{grid-item}
#
# ```{image} images/catherines-flagstaff.jpg
# :alt: Les Catherines
# :width: 220px
# :class: about-photo
# ```
# :::
# ::::
#
# ::: {.card}
# ### Upcoming shows
# - **June 20, 2026**: World Music Day· Littleton Brewery, Denver <br>
#   https://www.afdenver.org/event-rsvp/la-fete-de-la-musique-2026/
#   <br>
# - **June 27, 2026**: Tandoori Grill, Boulder <br>
#   For more info: <a href="images/Tandoori2026-06-27.jpg" target="_blank">View flyer</a>
#   <br>
# - **July 11, 2026**: The Muse, Lafayette
#   <br>
# - **July 12, 2026**: French Fest 2026, Cherry Creek
#   https://denverfrenchfest.com/
#   <br>
#   - **August 22, 2026**: Duets, Longmont
#   <br>
#
# <a href="contact" class="button">More info</a>
#
# :::
#
#
# ---
#
#
# ::::{grid} 2
# :gap: 2
# :class: responsive-grid
# :::{grid-item}
#
# (openmic)=
# ## CBArt Studios Open Mic
#
# In addition to performing, we organize and run the CBArt Studios Open Mic in Superior, a recurring gathering where musicians and listeners come together in a relaxed and supportive setting.
#
# Thanks to the generosity of CBArt Studios, which provides their beautiful space for live music, the open mic takes place on the first Friday of every other month. It is an evening dedicated to sharing music, discovering new voices, and creating connections within the local community.
#
# :::
#
#
# :::{grid-item}
# ```{image} images/openmic.mp4
# :alt: Les Catherines
# :width: 220px
# :class: about-photo
# ```
# :::
# ::::
#
# ::: {.card}
#
# ### Next Open Mic
# - Aug 7, 2026 · 6:00–8:00 PM · Superior, Colorado
# Registration opens 4 weeks before the open mic. <br>
# <a href="contact" class="button">More info</a>
#
# :::
