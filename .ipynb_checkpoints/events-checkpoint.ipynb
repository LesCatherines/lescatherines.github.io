# %% [markdown]
# # EVENTS
#
# Les Catherines regularly perform as a trio in intimate venues, restaurants and outdoor spaces, across Boulder County and the Denver area.
#
# We also host the CBArt Studios Open Mic in Superior, a relaxed gathering for musicians and listeners.
#
# Upcoming events and updates are regularly announced on our [social media →](contact)
#
# ----
#
# (performances)=
# ## Les Catherines Live
#
# ::::{grid} 1 1 2 2
# :gap: 2
# :class: responsive-grid
#
# :::{grid-item}
# :columns: 12 12 5 5
#
# Our trio performances feature a multilingual repertoire, blending styles and interpretations into a warm and engaging musical experience. We have performed at venues in the Front Range (Boulder, Superior, Lafayette, Longmont and Denver).
#
# :::
#
# :::{grid-item}
# :columns: 12 12 7 7
#
# ```{image} images/frenchfest2026.png
# :alt: Les Catherines
# :width: 100%
# :class: about-photo
# ```
# :::
# ::::
#
#
# (performances)=
# ## Les Catherines Live
#
# ::::{grid} 2
# :gap: 2
# :class: responsive-grid
# :::{grid-item}
#
# Our trio performances feature a multilingual repertoire, blending styles and interpretations into a warm and engaging musical experience. We have performed at venues in the Front Range (Boulder, Superior, Lafayette, Longmont and Denver).
#
# :::
#
# :::{grid-item}
#
# ```{image} images/frenchfest2026.png
# :alt: Les Catherines
# :width: 400px
# :class: about-photo
# ```
# :::
# ::::
#
# ::: {.card}
# ### Recent/Upcoming shows
#
# - **June 20, 2026** · World Music Day · Littleton Brewery, Denver
# **([Event details](https://www.afdenver.org/event-rsvp/la-fete-de-la-musique-2026/))**
#
# - **June 27, 2026** · Tandoori Grill, Boulder
# **([View flyer](images/Tandoori2026-06-27.jpg))**
#
# - **July 11, 2026** · The Muse, Lafayette
# **([Event details](https://www.giftedherd.org/po-benefit-concert))**
#
# - **July 12, 2026** · French Fest, Cherry Creek
# **([Event details](https://denverfrenchfest.com/))**
#
# - **August 22, 2026** · Duets, Longmont
# **([View flyer](images/2026-08-22-Duets.jpg))**
#
# - **September 19, 2026** · Tandoori Grill, Boulder
# **(More info coming soon)**
#
#
# <a href="contact" class="button">More info on social media</a>
#
# :::
#
#
# ---
#
#
# ::::{grid} 2
# :gap: 2
# :class: responsive-grid
# :::{grid-item}
#
# (openmic)=
# ## CBArt Studios Open Mic
#
# In addition to performing, we organize and run the CBArt Studios Open Mic in Superior, a recurring gathering where musicians and listeners come together in a relaxed and supportive setting.
#
# Thanks to the generosity of CBArt Studios, which provides their beautiful space for live music, the open mic takes place on the first Friday of every other month. It is an evening dedicated to sharing music, discovering new voices, and creating connections within the local community.
#
# :::
#
#
# :::{grid-item}
# ```{image} images/openmic.mp4
# :alt: Les Catherines
# :width: 220px
# :class: about-photo
# ```
# :::
# ::::
#
# ::: {.card}
#
# ### Next Open Mic
# - Oct 9, 2026 · 6:00–8:00 PM · Superior, Colorado<br>
# Registration opens 4 weeks before the open mic. <br><br>
# <a href="contact" class="button"> More info on social media</a>
#
# :::
